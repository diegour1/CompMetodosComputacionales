# %% [markdown]
# # Introduction to Python 3
#
# ## Object Oriented Programming
#
# ## Herramientas Computacionales
# ## Uniandes
#
# Based on [SoloLearn Python](https://www.sololearn.com/Play/Python)

# %% [markdown]
# Getter y setters

# %%
class Cat:
  ## constructor
  def __init__(self, color_param, legs_param):
    self.color = color_param
    self.legs = legs_param

  ## getter
  def get_color(self):
    return self.color

  ## setter
  def set_color(self, color_param):
    self.color = color_param

  def miau(self):
    print("miau")

# %%
felix = Cat("red", 3)

print(felix.get_color())
felix.set_color("blue")
print(felix.get_color())
felix.miau()
# Out:
# red
# blue
# miau

# %% [markdown]
# ## Class Constructor \__init__

# %%
class Cat:
  def __init__(self, color, legs):
    self.color = color
    self.legs = legs

# %%
# Class Objects
felix = Cat("ginger", 4)
rover = Cat("dog-colored", 4)
stumpy = Cat("brown", 3)

# %% [markdown]
# ## Methods

# %%
class Cat:
  # Constructor
  def __init__(self, color, legs):
    self.color = color
    self.legs = legs
  # Method
  def meow(self):
    print('miau')

# %%
felix = Cat("ginger", 4)
felix.meow()
# Out:
# miau

# %% [markdown]
# ## Inheritance

# %%
class Wolf:
  def __init__(self, name, color):
    self.name = name
    self.color = color

  def bark(self):
    print("Grr...")

# %%
class Dog(Wolf):

  def bark(self):
    print("Guau")

# %%
Tom = Dog("Tom", "Grey")

Tom.bark()
print(Tom.color)
print(Tom.name)
# Out:
# Guau
# Grey
# Tom

# %%
class Wolf:
  def __init__(self, name, color):
    self.name = name
    self.color = color

  def bark(self):
    print("Grr...")

# Class Dog inherits the attributes and methods of Wolf
class Dog(Wolf):
  pass
  # def bark(self):
  #   print("Woof")

# %%
husky = Dog("Max", "grey")
husky.bark()
# Out:
# Grr...

# %% [markdown]
# ## Super

# %%
class Wolf:
  def __init__(self, name, color):
    self.name = name
    self.color = color

  def bark(self):
    print("Grr...")

# Class Dog inherits the attributes and methods
class Dog(Wolf):
  #pass
   def bark(self):
     print("Woof")
     # Call the super class method
     super().bark()

# %%
husky = Dog("Max", "grey")
husky.bark()
# Out:
# Woof
# Grr...

# %% [markdown]
# ## Example
#
# One warrior and one knight with health = 50, the warrior has variable attack, the knight has an attack of 55.
# The knight attacks first, check who dies first.

# %%
class Warrior:
  def __init__(self, attack):
    self.health = 50
    self.attack = attack
  def is_alive(self):
    if self.health <= 0:
      print('is dead')
    else:
      print('is alive')

# %%
class Knight(Warrior):
  def __init__(self):
    self.health = 50
    self.attack = 55

# %%
def fight(knight, warrior):
  knight.health = knight.health - warrior.attack
  print('Knight:')
  knight.is_alive()
  print('Warrior')
  warrior.is_alive()
  if knight.health > 0:
    warrior.health = warrior.health - knight.attack
    print('Knight:')
    knight.is_alive()
    print('Warrior')
    warrior.is_alive()

# %%
david = Warrior(35)
felipe = Knight()

# %%
fight(felipe, david)
# Out:
# Knight:
# is alive
# Warrior
# is dead
# Knight:
# is alive
# Warrior
# is dead
